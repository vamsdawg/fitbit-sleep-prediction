# %%
import pandas as pd

activity_df1 = pd.read_csv("dailyActivity_merged_1.csv")
activity_df2 = pd.read_csv("dailyActivity_merged_2.csv")
display(activity_df1.head())
display(activity_df2.head())
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
activity_df = pd.concat([activity_df1, activity_df2])
display(activity_df.head())
display(activity_df.tail())
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
activity_df.to_csv('merged_activity_data.csv', index=False)

# %%
sleep_df = pd.read_csv("sleepDay_merged.csv")
display(sleep_df.head())
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
intensity_df1 = pd.read_csv("hourly_intensities_merged_1.csv")
intensity_df2 = pd.read_csv("hourly_intensities_merged_2.csv")
display(intensity_df1.head())
display(intensity_df2.head())
# Out:
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  3/12/2016 12:00:00 AM               0               0.0
# 1  1503960366   3/12/2016 1:00:00 AM               0               0.0
# 2  1503960366   3/12/2016 2:00:00 AM               0               0.0
# 3  1503960366   3/12/2016 3:00:00 AM               0               0.0
# 4  1503960366   3/12/2016 4:00:00 AM               0               0.0
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  4/12/2016 12:00:00 AM              20          0.333333
# 1  1503960366   4/12/2016 1:00:00 AM               8          0.133333
# 2  1503960366   4/12/2016 2:00:00 AM               7          0.116667
# 3  1503960366   4/12/2016 3:00:00 AM               0          0.000000
# 4  1503960366   4/12/2016 4:00:00 AM               0          0.000000

# %%
hourlyIntensities_df = pd.concat([intensity_df1, intensity_df2])
display(hourlyIntensities_df.head())
display(hourlyIntensities_df.tail())
# Out:
#            Id           ActivityHour  TotalIntensity  AverageIntensity
# 0  1503960366  3/12/2016 12:00:00 AM               0               0.0
# 1  1503960366   3/12/2016 1:00:00 AM               0               0.0
# 2  1503960366   3/12/2016 2:00:00 AM               0               0.0
# 3  1503960366   3/12/2016 3:00:00 AM               0               0.0
# 4  1503960366   3/12/2016 4:00:00 AM               0               0.0
#                Id           ActivityHour  TotalIntensity  AverageIntensity
# 22094  8877689391  5/12/2016 10:00:00 AM              12          0.200000
# 22095  8877689391  5/12/2016 11:00:00 AM              29          0.483333
# 22096  8877689391  5/12/2016 12:00:00 PM              93          1.550000
# 22097  8877689391   5/12/2016 1:00:00 PM               6          0.100000
# 22098  8877689391   5/12/2016 2:00:00 PM               9          0.150000

# %%
hourlyIntensities_df.to_csv('merged_intensity_data.csv', index=False)

# %%
steps_df1 = pd.read_csv("hourlySteps_merged_1.csv")
steps_df2 = pd.read_csv("hourlySteps_merged_2.csv")

# %%
steps_df = pd.concat([steps_df1, steps_df2])
display(steps_df.head())
display(steps_df.tail())
# Out:
#            Id           ActivityHour  StepTotal
# 0  1503960366  3/12/2016 12:00:00 AM          0
# 1  1503960366   3/12/2016 1:00:00 AM          0
# 2  1503960366   3/12/2016 2:00:00 AM          0
# 3  1503960366   3/12/2016 3:00:00 AM          0
# 4  1503960366   3/12/2016 4:00:00 AM          0
#                Id           ActivityHour  StepTotal
# 22094  8877689391  5/12/2016 10:00:00 AM        514
# 22095  8877689391  5/12/2016 11:00:00 AM       1407
# 22096  8877689391  5/12/2016 12:00:00 PM       3135
# 22097  8877689391   5/12/2016 1:00:00 PM        307
# 22098  8877689391   5/12/2016 2:00:00 PM        457

# %%
steps_df.to_csv('merged_steps_data.csv', index=False)

# %%
import pandas as pd

calories_df1 = pd.read_csv("hourlyCalories_merged_1.csv")
calories_df2 = pd.read_csv("hourlyCalories_merged_2.csv")

merged_calories = pd.concat([calories_df1, calories_df2])
merged_calories.to_csv('merged_calories_data.csv', index=False)

display(merged_calories.head())
display(merged_calories.tail())
# Out:
#            Id           ActivityHour  Calories
# 0  1503960366  3/12/2016 12:00:00 AM        48
# 1  1503960366   3/12/2016 1:00:00 AM        48
# 2  1503960366   3/12/2016 2:00:00 AM        48
# 3  1503960366   3/12/2016 3:00:00 AM        48
# 4  1503960366   3/12/2016 4:00:00 AM        48
#                Id           ActivityHour  Calories
# 22094  8877689391  5/12/2016 10:00:00 AM       126
# 22095  8877689391  5/12/2016 11:00:00 AM       192
# 22096  8877689391  5/12/2016 12:00:00 PM       321
# 22097  8877689391   5/12/2016 1:00:00 PM       101
# 22098  8877689391   5/12/2016 2:00:00 PM       113

# %%
import pandas as pd

heartrate_df1 = pd.read_csv("heartrate_seconds_merged_1.csv")
heartrate_df2 = pd.read_csv("heartrate_seconds_merged_2.csv")

merged_heartrate = pd.concat([heartrate_df1, heartrate_df2])
merged_heartrate.to_csv('merged_heartrate_data.csv', index=False)

display(merged_heartrate.head())
display(merged_heartrate.tail())
# Out:
#            Id                 Time  Value
# 0  2022484408  4/1/2016 7:54:00 AM   93.0
# 1  2022484408  4/1/2016 7:54:05 AM   91.0
# 2  2022484408  4/1/2016 7:54:10 AM   96.0
# 3  2022484408  4/1/2016 7:54:15 AM   98.0
# 4  2022484408  4/1/2016 7:54:20 AM  100.0
#                 Id                  Time  Value
# 670191  4388161847  4/21/2016 6:24:00 PM   94.0
# 670192  4388161847  4/21/2016 6:24:15 PM   95.0
# 670193  4388161847  4/21/2016 6:24:20 PM   94.0
# 670194  4388161847  4/21/2016 6:24:35 PM   96.0
# 670195     4388161                   NaN    NaN

# %%
import pandas as pd

weightLogInfo_df1 = pd.read_csv("weightLogInfo_merged_1.csv")
weightLofInfo_df2 = pd.read_csv("weightLogInfo_merged_2.csv")

merged_weightLogInfo = pd.concat([weightLogInfo_df1, weightLofInfo_df2])
merged_weightLogInfo.to_csv('merged_weightLogInfo_data.csv', index=False)

display(merged_weightLogInfo.head())
display(merged_weightLogInfo.tail())
# Out:
#            Id                  Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366  4/5/2016 11:59:59 PM   53.299999    117.506384  22.0
# 1  1927972279  4/10/2016 6:33:26 PM  129.600006    285.719105   NaN
# 2  2347167796  4/3/2016 11:59:59 PM   63.400002    139.773078  10.0
# 3  2873212765  4/6/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  4/7/2016 11:59:59 PM   57.200001    126.104416   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.969999            True  1459900799000
# 1  46.169998           False  1460313206000
# 2  24.770000            True  1459727999000
# 3  21.450001            True  1459987199000
# 4  21.650000            True  1460073599000
#             Id                  Date   WeightKg  WeightPounds  Fat        BMI  \
# 62  8877689391   5/6/2016 6:43:35 AM  85.000000    187.392923  NaN  25.440001
# 63  8877689391   5/8/2016 7:35:53 AM  85.400002    188.274775  NaN  25.559999
# ...
